# %%
# !pip install logging
# Out:
# ...
#   Using cached logging-0.4.9.6.tar.gz
#     Complete output from command python setup.py egg_info:
#     running egg_info
#     creating pip-egg-info/logging.egg-info
#     writing pip-egg-info/logging.egg-info/PKG-INFO
#     writing dependency_links to pip-egg-info/logging.egg-info/dependency_links.txt
#     writing top-level names to pip-egg-info/logging.egg-info/top_level.txt
#     writing manifest file 'pip-egg-info/logging.egg-info/SOURCES.txt'
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/0m/ndph5w8932v3cfslf4ghqvc80000gn/T/pip-build-o1x18ibz/logging/setup.py", line 13, in <module>
#         packages = ["logging"],
#       File "/anaconda3/lib/python3.6/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/anaconda3/lib/python3.6/distutils/dist.py", line 955, in run_commands
#         self.run_command(cmd)
# ...

# %%
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
 
sentences = [['first', 'sentence'], ['second', 'sentence']]
# train word2vec on the two sentences
model = gensim.models.Word2Vec(sentences, min_count=1)
# Out:
# 2018-01-17 20:07:27,903 : INFO : collecting all words and their counts
# 2018-01-17 20:07:27,905 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-01-17 20:07:27,906 : INFO : collected 3 word types from a corpus of 4 raw words and 2 sentences
# 2018-01-17 20:07:27,908 : INFO : Loading a fresh vocabulary
# 2018-01-17 20:07:27,910 : INFO : min_count=1 retains 3 unique words (100% of original 3, drops 0)
# 2018-01-17 20:07:27,912 : INFO : min_count=1 leaves 4 word corpus (100% of original 4, drops 0)
# 2018-01-17 20:07:27,915 : INFO : deleting the raw counts dictionary of 3 items
# 2018-01-17 20:07:27,918 : INFO : sample=0.001 downsamples 3 most-common words
# 2018-01-17 20:07:27,920 : INFO : downsampling leaves estimated 0 word corpus (5.7% of prior 4)
# 2018-01-17 20:07:27,924 : INFO : estimated required memory for 3 words and 100 dimensions: 3900 bytes
# 2018-01-17 20:07:27,927 : INFO : resetting layer weights
# ...

# %%
model

# %%
import pandas as pd
data_with_captions = pd.read_pickle("bestFiends.pickle")

# %%
captions = pd.read_pickle("bestFiends_captions.pickle")
captions
# Out:
#          end    start                                      text     video_id
# 0      4.129    0.030       this video is an ad for seriously I  Q5MvUGnpDp4
# 1     10.230    5.810    don't know the ever just feel like you  Q5MvUGnpDp4
# 2     18.570    8.460    wake up and you do the same thing over  Q5MvUGnpDp4
# 3     23.640   10.230   and over again like nothing changes are  Q5MvUGnpDp4
# 4     26.180   18.570  you saying right now I just need to find  Q5MvUGnpDp4
# 5     26.180   23.640                                    myself  Q5MvUGnpDp4
# 6     33.190   28.570                                   [Music]  Q5MvUGnpDp4
# 7     39.630   36.380                                   [Music]  Q5MvUGnpDp4
# 8     48.760   45.370                              what you use  Q5MvUGnpDp4
# 9     56.840   49.489        it's got hard games you're feeling  Q5MvUGnpDp4
# 10    59.180   53.899  something and I need to help I just feel  Q5MvUGnpDp4
# ...

# %%
text = list(captions.text[captions.video_id == 'nmeZkmtq-lo'])

# %%
model = gensim.models.word2vec.Word2Vec(text, size=200)
# Out:
# 2018-01-17 20:21:29,609 : INFO : collecting all words and their counts
# 2018-01-17 20:21:29,612 : WARNING : Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.
# 2018-01-17 20:21:29,614 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-01-17 20:21:29,618 : INFO : collected 60 word types from a corpus of 14132 raw words and 391 sentences
# 2018-01-17 20:21:29,621 : INFO : Loading a fresh vocabulary
# 2018-01-17 20:21:29,623 : INFO : min_count=5 retains 40 unique words (66% of original 60, drops 20)
# 2018-01-17 20:21:29,624 : INFO : min_count=5 leaves 14095 word corpus (99% of original 14132, drops 37)
# 2018-01-17 20:21:29,626 : INFO : deleting the raw counts dictionary of 60 items
# 2018-01-17 20:21:29,629 : INFO : sample=0.001 downsamples 25 most-common words
# 2018-01-17 20:21:29,630 : INFO : downsampling leaves estimated 2554 word corpus (18.1% of prior 14095)
# ...

# %%
model.score(['fiend'])
# Out:
# 2018-01-17 20:23:40,013 : INFO : scoring sentences with 3 workers on 40 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 and negative=5
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-9992052187d2> in <module>()
# ----> 1 model.score(['fiend'])
#
# /anaconda3/lib/python3.6/site-packages/gensim/models/word2vec.py in score(self, sentences, total_sentences, chunksize, queue_factor, report_delay)
#    1170         if not self.hs:
#    1171             raise RuntimeError(
# -> 1172                 "We have currently only implemented score for the hierarchical softmax scheme, "
#    1173                 "so you need to have run word2vec with hs=1 and negative=0 for this to work."
#    1174             )
#
# ...
